# %%
import pandas as pd
df = pd.read_csv("virat.csv")
df.head()
# Out:
#    No.  Runs       Against  Position  Innings  \
# 0    1   107     Sri Lanka         4        2
# 1    2   102    Bangladesh         3        2
# 2    3   118     Australia         3        2
# 3    4   105   New Zealand         3        1
# 4    5   100    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
df.sample()
# Out:
#     No.  Runs      Against  Position  Innings  \
# 75   76   121  West Indies         4        1
#
#                                Venue Ground       Date Result
# 75  Queen's Park Oval, Port of Spain   Away  20-Jul-23  Drawn

# %%
df.head()
# Out:
#    No.  Runs       Against  Position  Innings  \
# 0    1   107     Sri Lanka         4        2
# 1    2   102    Bangladesh         3        2
# 2    3   118     Australia         3        2
# 3    4   105   New Zealand         3        1
# 4    5   100    Bangladesh         4        1
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won
# 3               Nehru Stadium, Guwahati   Home  28-Nov-10    Won
# 4  Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11    Won

# %%
df.tail()
# Out:
#     No.  Runs       Against  Position  Innings  \
# 75   76   121   West Indies         4        1
# 76   77   122      Pakistan         3        1
# 77   78   103    Bangladesh         3        2
# 78   79   101  South Africa         3        1
# 79   80   117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 75               Queen's Park Oval, Port of Spain     Away  20-Jul-23  Drawn
# 76                  R. Premadasa Stadium, Colombo  Neutral  11-Sep-23    Won
# 77  Maharashtra Cricket Association Stadium, Pune     Home  19-Oct-23    Won
# 78                          Eden Gardens, Kolkata      NaN      5-Nov    Won
# 79                       Wankhede Stadium, Mumbai     Home  15-Nov-23    Won

# %%
df.describe()
# Out:
#            No.        Runs   Position   Innings
# count  80.0000   80.000000  80.000000  80.00000
# mean   40.5000  131.550000   3.500000   1.67500
# std    23.2379   35.094772   0.656033   0.67082
# min     1.0000  100.000000   2.000000   1.00000
# 25%    20.7500  107.000000   3.000000   1.00000
# 50%    40.5000  118.500000   3.000000   2.00000
# 75%    60.2500  139.250000   4.000000   2.00000
# max    80.0000  254.000000   6.000000   4.00000

# %%
df.describe(include="all")
# Out:
#             No.        Runs     Against   Position   Innings  \
# count   80.0000   80.000000          80  80.000000  80.00000
# unique      NaN         NaN          15        NaN       NaN
# top         NaN         NaN   Australia        NaN       NaN
# freq        NaN         NaN          16        NaN       NaN
# mean    40.5000  131.550000         NaN   3.500000   1.67500
# std     23.2379   35.094772         NaN   0.656033   0.67082
# min      1.0000  100.000000         NaN   2.000000   1.00000
# 25%     20.7500  107.000000         NaN   3.000000   1.00000
# 50%     40.5000  118.500000         NaN   3.000000   2.00000
# 75%     60.2500  139.250000         NaN   4.000000   2.00000
# max     80.0000  254.000000         NaN   6.000000   4.00000
#
#                           Venue Ground      Date Result
# count                        80     79        80     80
# unique                       49      3        79      6
# top     Adelaide Oval, Adelaide   Home  9-Dec-14    Won
# ...

# %%
a = df['Venue']
a
# Out:
# 0                             Eden Gardens, Kolkata
# 1              Sher-e-Bangla Cricket Stadium, Dhaka
# 2                  APCA-VDCA Stadium, Visakhapatnam
# 3                           Nehru Stadium, Guwahati
# 4              Sher-e-Bangla Cricket Stadium, Dhaka
#                           ...
# 75                 Queen's Park Oval, Port of Spain
# 76                    R. Premadasa Stadium, Colombo
# 77    Maharashtra Cricket Association Stadium, Pune
# 78                            Eden Gardens, Kolkata
# 79                         Wankhede Stadium, Mumbai
# Name: Venue, Length: 80, dtype: object

# %%
b = df[["Venue","Runs"]]
b
# Out:
#                                             Venue  Runs
# 0                           Eden Gardens, Kolkata   107
# 1            Sher-e-Bangla Cricket Stadium, Dhaka   102
# 2                APCA-VDCA Stadium, Visakhapatnam   118
# 3                         Nehru Stadium, Guwahati   105
# 4            Sher-e-Bangla Cricket Stadium, Dhaka   100
# ..                                            ...   ...
# 75               Queen's Park Oval, Port of Spain   121
# 76                  R. Premadasa Stadium, Colombo   122
# 77  Maharashtra Cricket Association Stadium, Pune   103
# 78                          Eden Gardens, Kolkata   101
# 79                       Wankhede Stadium, Mumbai   117
#
# [80 rows x 2 columns]

# %%
df['Runs']
# Out:
# 0     107
# 1     102
# 2     118
# 3     105
# 4     100
#      ...
# 75    121
# 76    122
# 77    103
# 78    101
# 79    117
# Name: Runs, Length: 80, dtype: int64

# %%
df['Runs'].mean()
# Out:
# np.float64(131.55)

# %%
df['Runs'].median()
# Out:
# np.float64(118.5)

# %%
df['Runs'].mode()
# Out:
# 0    103
# Name: Runs, dtype: int64

# %%
df['Venue'].count
# Out:
# <bound method Series.count of 0                             Eden Gardens, Kolkata
# 1              Sher-e-Bangla Cricket Stadium, Dhaka
# 2                  APCA-VDCA Stadium, Visakhapatnam
# 3                           Nehru Stadium, Guwahati
# 4              Sher-e-Bangla Cricket Stadium, Dhaka
#                           ...
# 75                 Queen's Park Oval, Port of Spain
# 76                    R. Premadasa Stadium, Colombo
# 77    Maharashtra Cricket Association Stadium, Pune
# 78                            Eden Gardens, Kolkata
# 79                         Wankhede Stadium, Mumbai
# Name: Venue, Length: 80, dtype: object>

# %%
df['Position'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Position'>

# %%
df.isnull().sum()
# Out:
# No.         0
# Runs        0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      1
# Date        0
# Result      0
# dtype: int64

# %%
df[df['Runs'].isnull()]
# Out:
# Empty DataFrame
# Columns: [No., Runs, Against, Position, Innings, Venue, Ground, Date, Result]
# Index: []

# %%
df["Average"] = df['Runs'].fillna(df["Runs"].mean())

# %%
df[df['Runs'].isnull()]
# Out:
# Empty DataFrame
# Columns: [No., Runs, Against, Position, Innings, Venue, Ground, Date, Result, Average]
# Index: []

# %%
df['Average'].plot(kind="line")
# Out:
# <Axes: >

# %%
pd.set_option=("display.max_rows",None)
pd.set_option=("display.max_columns",None)

# %%
df.loc[[2,5,8,18,60]]
# Out:
#     No.  Runs       Against  Position  Innings  \
# 2     3   118     Australia         3        2
# 5     6   107       England         4        1
# 8     9   116     Australia         6        2
# 18   19   115      Zimbabwe         3        2
# 60   61   157   West Indies         3        1
#
#                                       Venue Ground       Date      Result  \
# 2          APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10         Won
# 5                   Sophia Gardens, Cardiff   Away  16-Sep-11  Lost (D/L)
# 8                   Adelaide Oval, Adelaide   Away  24-Jan-12        Lost
# 18               Harare Sports Club, Harare   Away  24-Jul-13         Won
# 60  ACA-VDCA Cricket Stadium, Visakhapatnam   Home  24-Oct-18        Tied
#
#     Average
# 2       118
# 5       107
# 8       116
# 18      115
# 60      157

# %%
df.iloc[[0,8]]
# Out:
#    No.  Runs     Against  Position  Innings                    Venue Ground  \
# 0    1   107   Sri Lanka         4        2    Eden Gardens, Kolkata   Home
# 8    9   116   Australia         6        2  Adelaide Oval, Adelaide   Away
#
#         Date Result  Average
# 0  24-Dec-09    Won      107
# 8  24-Jan-12   Lost      116

# %%
df.groupby("Position").describe()
# Out:
#            No.                                                       Runs  \
#          count       mean        std   min    25%   50%   75%   max count
# Position
# 2          1.0  71.000000        NaN  71.0  71.00  71.0  71.0  71.0   1.0
# 3         43.0  43.581395  23.889859   2.0  22.00  46.0  64.5  80.0  43.0
# 4         32.0  38.687500  21.590675   1.0  26.25  39.0  54.0  76.0  32.0
# 5          3.0  16.000000   1.000000  15.0  15.50  16.0  16.5  17.0   3.0
# 6          1.0   9.000000        NaN   9.0   9.00   9.0   9.0   9.0   1.0
#
#                       ... Innings      Average                                \
#                 mean  ...     75%  max   count        mean        std    min
# Position              ...
# 2         122.000000  ...     1.0  1.0     1.0  122.000000        NaN  122.0
# 3         121.279070  ...     2.0  2.0    43.0  121.279070  18.917522  100.0
# 4         148.687500  ...     2.0  4.0    32.0  148.687500  46.060575  100.0
# ...

# %%
df
# Out:
#     No.  Runs       Against  Position  Innings  \
# 0     1   107     Sri Lanka         4        2
# 1     2   102    Bangladesh         3        2
# 2     3   118     Australia         3        2
# 3     4   105   New Zealand         3        1
# 4     5   100    Bangladesh         4        1
# ..  ...   ...           ...       ...      ...
# 75   76   121   West Indies         4        1
# 76   77   122      Pakistan         3        1
# 77   78   103    Bangladesh         3        2
# 78   79   101  South Africa         3        1
# 79   80   117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result  \
# 0                           Eden Gardens, Kolkata     Home  24-Dec-09    Won
# 1            Sher-e-Bangla Cricket Stadium, Dhaka     Away  11-Jan-10    Won
# 2                APCA-VDCA Stadium, Visakhapatnam     Home  20-Oct-10    Won
# 3                         Nehru Stadium, Guwahati     Home  28-Nov-10    Won
# ...

# %%
df.to_excel("virat_kholi's_centuries_cleaned.xlsx", index=False)
